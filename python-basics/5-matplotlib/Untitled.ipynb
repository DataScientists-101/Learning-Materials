# %%
import matplotlib.pyplot as plt
import numpy as np
t = np.arange(0., 5., 0.2) 
x1=[1,2,3,4]
y1=[4,5,6,7]
x2=[5,6,7,8]
y2=[4,5,7,9]
plt.title("demo diagram")
#plt.plot(t,t**2,'bo',label='^2')
#plt.plot(t,t**2.5,'r--',label='^2.5')
#plt.plot(t,t**3,'g^',label='^3')
lines=plt.plot(x1,y1,x2,y2)
plt.setp(lines[0],color='r',linewidth='2.0')
plt.setp(lines[1],color='b',linewidth='2.0')
plt.xlabel("indices")
plt.ylabel("numbers")
#plt.grid()
#plt.legend()
plt.show()
